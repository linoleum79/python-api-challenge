# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=metric&"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"lat={city_lat}&lon={city_lng}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city.city_name))

    # Add 1 to the record count
    record_count += 1
     # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url + city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city.city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | selfoss
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | wailua homesteads
# Processing Record 7 of Set 1 | crane
# Processing Record 8 of Set 1 | la ronge
# Processing Record 9 of Set 1 | colonia
# Processing Record 10 of Set 1 | el calafate
# Processing Record 11 of Set 1 | berezovyy
# Processing Record 12 of Set 1 | walvis bay
# Processing Record 13 of Set 1 | guasdualito
# Processing Record 14 of Set 1 | bikenibeu village
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | haiku-pauwela
# Processing Record 19 of Set 1 | lihue
# Processing Record 20 of Set 1 | am timan
# Processing Record 21 of Set 1 | reggane
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | vorgashor
# Processing Record 24 of Set 1 | vilyuysk
# Processing Record 25 of Set 1 | remire-montjoly
# Processing Record 26 of Set 1 | dhidhdhoo
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | margaret river
# Processing Record 31 of Set 1 | invercargill
# Processing Record 32 of Set 1 | colares
# Processing Record 33 of Set 1 | el fasher
# Processing Record 34 of Set 1 | hats'avan
# Processing Record 35 of Set 1 | aras-asan
# Processing Record 36 of Set 1 | hawaiian paradise park
# Processing Record 37 of Set 1 | syktyvkar
# Processing Record 38 of Set 1 | taiohae
# Processing Record 39 of Set 1 | blackmans bay
# Processing Record 40 of Set 1 | eastham
# Processing Record 41 of Set 1 | chumphon
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | susuman
# Processing Record 45 of Set 1 | dzialdowo
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | port-aux-francais
# Processing Record 50 of Set 1 | piacabucu
# Processing Record 0 of Set 2 | adamstown
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | puerto natales
# Processing Record 3 of Set 2 | city of balikpapan
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | touba
# Processing Record 6 of Set 2 | la passe
# Processing Record 7 of Set 2 | puerto ayacucho
# Processing Record 8 of Set 2 | murzuq
# Processing Record 9 of Set 2 | robertsport
# Processing Record 10 of Set 2 | nago
# Processing Record 11 of Set 2 | lasem
# Processing Record 12 of Set 2 | iskateley
# Processing Record 13 of Set 2 | rawson
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | howard springs
# Processing Record 16 of Set 2 | praia da vitoria
# Processing Record 17 of Set 2 | happy valley-goose bay
# Processing Record 18 of Set 2 | kasongo-lunda
# Processing Record 19 of Set 2 | talara
# Processing Record 20 of Set 2 | edinburgh of the seven seas
# Processing Record 21 of Set 2 | atafu village
# Processing Record 22 of Set 2 | chonchi
# Processing Record 23 of Set 2 | mikun'
# Processing Record 24 of Set 2 | isafjordur
# Processing Record 25 of Set 2 | lata
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | puerto baquerizo moreno
# Processing Record 28 of Set 2 | olonkinbyen
# Processing Record 29 of Set 2 | estevan
# Processing Record 6 of Set 4 | enewetak
# Processing Record 7 of Set 4 | tual
# Processing Record 8 of Set 4 | uturoa
# Processing Record 9 of Set 4 | nkhotakota
# Processing Record 10 of Set 4 | mahina
# Processing Record 11 of Set 4 | mbamba bay
# Processing Record 12 of Set 4 | punta arenas
# Processing Record 13 of Set 4 | agat village
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | vadso
# Processing Record 17 of Set 4 | conceicao da barra
# Processing Record 18 of Set 4 | dalbandin
# Processing Record 19 of Set 4 | yaren
# Processing Record 20 of Set 4 | hankasalmi
# Processing Record 21 of Set 4 | rio grande
# Processing Record 22 of Set 4 | ferozepore
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | saipan
# Processing Record 25 of Set 4 | vereshchagino
# Processing Record 26 of Set 4 | grand falls-windsor
# Processing Record 27 of Set 4 | altamira
# Processing Record 28 of Set 4 | tolanaro
# Processing Record 29 of Set 4 | muhos
# Processing Record 30 of Set 4 | arar
# Processing Record 31 of Set 4 | capitao poco
# Processing Record 32 of Set 4 | quelimane
# Processing Record 33 of Set 4 | san jose village
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | zhangjiakou
# Processing Record 36 of Set 4 | tranovaho
# Processing Record 37 of Set 4 | st. john's
# Processing Record 38 of Set 4 | greymouth
# Processing Record 39 of Set 4 | detroit lakes
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | sandnessjoen
# Processing Record 42 of Set 4 | midvagur
# Processing Record 43 of Set 4 | shingu
# Processing Record 44 of Set 4 | revda
# Processing Record 45 of Set 4 | cartagena
# Processing Record 46 of Set 4 | kataragama
# Processing Record 47 of Set 4 | bonthe
# Processing Record 48 of Set 4 | fort mcmurray
# Processing Record 49 of Set 4 | takamaka
# Processing Record 0 of Set 5 | thanh hoa
# Processing Record 1 of Set 5 | viedma
# Processing Record 2 of Set 5 | chui
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | kolonia
# Processing Record 5 of Set 5 | port mathurin
# Processing Record 6 of Set 5 | utrik
# Processing Record 7 of Set 5 | puerto san carlos
# Processing Record 8 of Set 5 | qamdo
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | maputo
# Processing Record 11 of Set 5 | agadez
# Processing Record 12 of Set 5 | mweka
# Processing Record 13 of Set 5 | lazaro cardenas
# Processing Record 14 of Set 5 | yambio
# Processing Record 15 of Set 5 | neubrandenburg
# Processing Record 16 of Set 5 | ciudad bolivar
# Processing Record 17 of Set 5 | sinabang
# Processing Record 18 of Set 5 | al mindak
# Processing Record 19 of Set 5 | jimeta
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | yuryuzan'
# Processing Record 23 of Set 5 | mahajanga
# Processing Record 24 of Set 5 | emerald
# Processing Record 25 of Set 5 | angaur state
# Processing Record 26 of Set 5 | brokopondo
# Processing Record 27 of Set 5 | lerwick
# Processing Record 28 of Set 5 | florence
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | winejok
# Processing Record 31 of Set 5 | bandarbeyla
# Processing Record 32 of Set 5 | acarau
# Processing Record 33 of Set 5 | xilin hot
# Processing Record 34 of Set 5 | troitsko-pechorsk
# Processing Record 35 of Set 5 | saudarkrokur
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | port-vila
# Processing Record 38 of Set 5 | vilyuchinsk
# Processing Record 39 of Set 5 | saint-joseph
# Processing Record 40 of Set 5 | gadzhiyevo
# Processing Record 41 of Set 5 | ola
# Processing Record 42 of Set 5 | fuvahmulah
# Processing Record 43 of Set 5 | windhoek
# Processing Record 44 of Set 5 | bembereke
# Processing Record 45 of Set 5 | chinde
# Processing Record 46 of Set 5 | kudahuvadhoo
# Processing Record 47 of Set 5 | ermoupolis
# Processing Record 48 of Set 5 | general roca
# Processing Record 49 of Set 5 | moundou
# Processing Record 0 of Set 6 | camayenne
# Processing Record 1 of Set 6 | ust'-ilimsk
# Processing Record 2 of Set 6 | forster
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | guangyuan
# Processing Record 6 of Set 6 | gusinoozyorsk
# Processing Record 7 of Set 6 | revelstoke
# Processing Record 8 of Set 6 | badger
# Processing Record 9 of Set 6 | monrovia
# Processing Record 10 of Set 6 | kapan
# Processing Record 11 of Set 6 | gamba
# Processing Record 12 of Set 6 | palikir - national government center
# Processing Record 13 of Set 6 | paraguari
# Processing Record 14 of Set 6 | vingt cinq
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | nouadhibou
# Processing Record 17 of Set 6 | fale old settlement
# Processing Record 18 of Set 6 | turkeli
# Processing Record 19 of Set 6 | xining
# Processing Record 20 of Set 6 | ijuw
# Processing Record 21 of Set 6 | siracusa
# Processing Record 22 of Set 6 | funafuti
# Processing Record 23 of Set 6 | yangor
# Processing Record 24 of Set 6 | kenora
# Processing Record 25 of Set 6 | stanley
# Processing Record 26 of Set 6 | labrador city
# Processing Record 27 of Set 6 | nyurba
# Processing Record 28 of Set 6 | schesslitz
# Processing Record 29 of Set 6 | kingscliff
# Processing Record 30 of Set 6 | gulnar
# Processing Record 31 of Set 6 | mbanza kongo
# Processing Record 32 of Set 6 | kourou
# Processing Record 33 of Set 6 | sisimiut
# Processing Record 34 of Set 6 | puerto gaitan
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | san luis de la loma
# Processing Record 37 of Set 6 | namibe
# Processing Record 38 of Set 6 | nobeoka
# Processing Record 39 of Set 6 | san antonio de pale
# Processing Record 40 of Set 6 | nemuro
# Processing Record 41 of Set 6 | paranapanema
# Processing Record 42 of Set 6 | praia
# Processing Record 43 of Set 6 | moranbah
# Processing Record 44 of Set 6 | looe
# Processing Record 45 of Set 6 | aasiaat
# Processing Record 46 of Set 6 | weno
# Processing Record 47 of Set 6 | zhezqazghan
# Processing Record 48 of Set 6 | port shepstone
# Processing Record 49 of Set 6 | cabedelo
# Processing Record 0 of Set 7 | tralee
# Processing Record 1 of Set 7 | santana
# Processing Record 2 of Set 7 | murray bridge
# Processing Record 3 of Set 7 | igarka
# Processing Record 4 of Set 7 | tobelo
# Processing Record 5 of Set 7 | char bhadrasan
# Processing Record 6 of Set 7 | dryden
# Processing Record 7 of Set 7 | bulungu
# Processing Record 8 of Set 7 | guerrero negro
# Processing Record 9 of Set 7 | ishigaki
# Processing Record 10 of Set 7 | margate
# Processing Record 11 of Set 7 | nieuw nickerie
# Processing Record 12 of Set 7 | 'ohonua
# Processing Record 13 of Set 7 | minas de marcona
# Processing Record 14 of Set 7 | 'ain deheb
# Processing Record 15 of Set 7 | great bend
# Processing Record 16 of Set 7 | loreto
# Processing Record 17 of Set 7 | sokone
# Processing Record 18 of Set 7 | conde
# Processing Record 19 of Set 7 | mumbai
# Processing Record 20 of Set 7 | merritt island
# Processing Record 21 of Set 7 | leua
# Processing Record 22 of Set 7 | miyanoura
# Processing Record 23 of Set 7 | kissidougou
# Processing Record 24 of Set 7 | anloga
# Processing Record 25 of Set 7 | thinadhoo
# Processing Record 26 of Set 7 | kuta
# Processing Record 27 of Set 7 | tshabong
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | tobi village
# Processing Record 30 of Set 7 | krasnokamensk
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | constantia
# Processing Record 33 of Set 7 | luchegorsk
# Processing Record 34 of Set 7 | wangkui
# Processing Record 35 of Set 7 | taulaga
# Processing Record 36 of Set 7 | najran
# Processing Record 37 of Set 7 | ghat
# Processing Record 38 of Set 7 | attapeu
# Processing Record 39 of Set 7 | vorkuta
# Processing Record 40 of Set 7 | amos
# Processing Record 41 of Set 7 | shahpur
# Processing Record 42 of Set 7 | pegnitz
# Processing Record 43 of Set 7 | mbekenyera
# Processing Record 44 of Set 7 | undurkhaan
# Processing Record 45 of Set 7 | tanda
# Processing Record 46 of Set 7 | basco
# Processing Record 47 of Set 7 | lucapa
# Processing Record 48 of Set 7 | conception bay south
# Processing Record 49 of Set 7 | port moresby
# Processing Record 0 of Set 8 | kapa'a
# Processing Record 1 of Set 8 | ikalamavony
# Processing Record 2 of Set 8 | chadan
# Processing Record 3 of Set 8 | bindki
# Processing Record 4 of Set 8 | floro
# Processing Record 5 of Set 8 | toropets
# Processing Record 6 of Set 8 | buka
# Processing Record 7 of Set 8 | capranica
# Processing Record 8 of Set 8 | portel
# Processing Record 9 of Set 8 | primero de mayo
# Processing Record 10 of Set 8 | fedorovskiy
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | zahedan
# Processing Record 13 of Set 8 | volgodonsk
# Processing Record 32 of Set 9 | arteche
# Processing Record 33 of Set 9 | malango
# Processing Record 34 of Set 9 | toledo
# Processing Record 35 of Set 9 | laguna
# Processing Record 36 of Set 9 | warren
# Processing Record 37 of Set 9 | poronaysk
# Processing Record 38 of Set 9 | pangai
# Processing Record 39 of Set 9 | yangambi
# Processing Record 40 of Set 9 | karachi
# Processing Record 41 of Set 9 | siqueira campos
# Processing Record 42 of Set 9 | hammerfest
# Processing Record 43 of Set 9 | bubaque
# Processing Record 44 of Set 9 | brisas barra de suchiate
# Processing Record 45 of Set 9 | hamilton
# Processing Record 46 of Set 9 | kisangani
# Processing Record 47 of Set 9 | fengxiang
# Processing Record 48 of Set 9 | sanctuary point
# Processing Record 49 of Set 9 | kasongo
# Processing Record 0 of Set 10 | tondano
# Processing Record 1 of Set 10 | vanimo
# Processing Record 2 of Set 10 | namdrik
# Processing Record 3 of Set 10 | reuleuet
# Processing Record 4 of Set 10 | cuajinicuilapa
# Processing Record 5 of Set 10 | saint-philippe
# Processing Record 6 of Set 10 | lospalos
# Processing Record 7 of Set 10 | ugoofaaru
# Processing Record 8 of Set 10 | bonao
# Processing Record 9 of Set 10 | barreirinha
# Processing Record 10 of Set 10 | st ives
# Processing Record 11 of Set 10 | sao joao da barra
# Processing Record 12 of Set 10 | aitape
# Processing Record 13 of Set 10 | qorveh
# Processing Record 14 of Set 10 | kallar kahar
# Processing Record 15 of Set 10 | les cayes
# Processing Record 16 of Set 10 | nagqu
# Processing Record 17 of Set 10 | oranjemund
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | hardeeville
# Processing Record 20 of Set 10 | kone
# Processing Record 21 of Set 10 | al kharj
# Processing Record 22 of Set 10 | ciudad melchor muzquiz
# Processing Record 23 of Set 10 | bac lieu
# Processing Record 24 of Set 10 | hadibu
# Processing Record 25 of Set 10 | xinyuan
# Processing Record 26 of Set 10 | vernon
# Processing Record 27 of Set 10 | gresovskiy
# Processing Record 28 of Set 10 | salida
# Processing Record 29 of Set 10 | tughyl
# Processing Record 30 of Set 10 | mabaruma
# Processing Record 31 of Set 10 | katsuren-haebaru
# Processing Record 32 of Set 10 | lanivtsi
# Processing Record 33 of Set 10 | bechar
# Processing Record 34 of Set 10 | trairi
# Processing Record 35 of Set 10 | hastings
# Processing Record 36 of Set 10 | macapa
# Processing Record 37 of Set 10 | touros
# Processing Record 38 of Set 10 | shihezi
# Processing Record 39 of Set 10 | castlegar
# Processing Record 40 of Set 10 | urangan
# Processing Record 41 of Set 10 | gurupi
# Processing Record 42 of Set 10 | xichang
# Processing Record 43 of Set 10 | biltine
# Processing Record 44 of Set 10 | nantucket
# Processing Record 45 of Set 10 | topolobampo
# Processing Record 46 of Set 10 | port alfred
# Processing Record 47 of Set 10 | crieff
# Processing Record 48 of Set 10 | uliastay
# Processing Record 49 of Set 10 | sungai penuh
# Processing Record 0 of Set 11 | kidal
# Processing Record 1 of Set 11 | nadym
# Processing Record 2 of Set 11 | riberalta
# Processing Record 3 of Set 11 | lillehammer
# Processing Record 4 of Set 11 | puerto deseado
# Processing Record 5 of Set 11 | al bardiyah
# Processing Record 6 of Set 11 | coquimbo
# Processing Record 7 of Set 11 | twin falls
# Processing Record 8 of Set 11 | beyneu
# Processing Record 9 of Set 11 | yaring
# Processing Record 10 of Set 11 | eirunepe
# Processing Record 11 of Set 11 | mukalla
# Processing Record 12 of Set 11 | sokoni
# Processing Record 13 of Set 11 | atyashevo
# Processing Record 14 of Set 11 | kapit
# Processing Record 15 of Set 11 | matoury
# Processing Record 16 of Set 11 | livingston
# Processing Record 17 of Set 11 | clinton
# Processing Record 18 of Set 11 | kilindoni
# Processing Record 19 of Set 11 | butte
# Processing Record 20 of Set 11 | fort st. john
# Processing Record 21 of Set 11 | mincivan
# Processing Record 22 of Set 11 | magadan
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | valparaiso
# Processing Record 25 of Set 11 | nichinan
# Processing Record 26 of Set 11 | ambovombe
# Processing Record 27 of Set 11 | north bay
# Processing Record 28 of Set 11 | ebeltoft
# Processing Record 29 of Set 11 | mangrol
# Processing Record 30 of Set 11 | dinghaicun
# Processing Record 31 of Set 11 | south sioux city
# Processing Record 32 of Set 11 | lafia
# Processing Record 33 of Set 11 | yuza
# Processing Record 34 of Set 11 | shalkar
# Processing Record 35 of Set 11 | kailua-kona
# Processing Record 36 of Set 11 | juba
# Processing Record 37 of Set 11 | pauini
# Processing Record 38 of Set 11 | bumba
# Processing Record 39 of Set 11 | nandyal
# Processing Record 40 of Set 11 | egilsstadir
# Processing Record 41 of Set 11 | clarence town
# Processing Record 42 of Set 11 | nar'yan-mar
# Processing Record 43 of Set 11 | lorengau
# Processing Record 44 of Set 11 | norilsk
# Processing Record 45 of Set 11 | arraial do cabo
# Processing Record 46 of Set 11 | zabol
# Processing Record 47 of Set 11 | smidovich
# Processing Record 48 of Set 11 | bulancak
# Processing Record 49 of Set 11 | saint-girons
# Processing Record 0 of Set 12 | boiling springs
# Processing Record 1 of Set 12 | pleven
# Processing Record 2 of Set 12 | navia
# Processing Record 3 of Set 12 | olinda
# Processing Record 4 of Set 12 | laojunmiao
# Processing Record 5 of Set 12 | parauapebas
# Processing Record 6 of Set 12 | nelson bay
# Processing Record 7 of Set 12 | timimoun
# Processing Record 8 of Set 12 | anabar
# Processing Record 9 of Set 12 | lesozavodsk
# Processing Record 10 of Set 12 | nishinoomote
# Processing Record 11 of Set 12 | diano marina
# Processing Record 12 of Set 12 | ubinskoye
# Processing Record 13 of Set 12 | bull savanna
# Processing Record 14 of Set 12 | yuzhno-kurilsk
# Processing Record 15 of Set 12 | calbuco
# Processing Record 16 of Set 12 | soio
# Processing Record 17 of Set 12 | manati
# Processing Record 18 of Set 12 | mulanje
# Processing Record 19 of Set 12 | tikapur
# Processing Record 20 of Set 12 | khandyga
# Processing Record 21 of Set 12 | yagry
# Processing Record 22 of Set 12 | axim
# Processing Record 23 of Set 12 | shanga
# Processing Record 24 of Set 12 | boshan
# Processing Record 25 of Set 12 | dawei
# Processing Record 26 of Set 12 | alo
# Processing Record 27 of Set 12 | anzio
# Processing Record 28 of Set 12 | verkhnevilyuysk
# Processing Record 29 of Set 12 | amga
# Processing Record 30 of Set 12 | kandi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     jamestown -23.2667 -55.5333     24.41        29           0        2.95
# 1  puerto ayora -23.2667 -55.5333     24.41        29           0        2.95
# 2       selfoss -23.2667 -55.5333     24.41        29           0        2.95
# 3       iqaluit -23.2667 -55.5333     24.41        29           0        2.95
# 4      thompson -23.2667 -55.5333     24.41        29           0        2.95
#
#   Country        Date
# 0      PY  1694806651
# 1      PY  1694806651
# 2      PY  1694806651
# 3      PY  1694806651
# 4      PY  1694806651

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %%
# set the current date variable for use by the scatter plot titles
current_date = time.strftime("%Y-%m-%d")

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, s=75, edgecolors="black", linewidths=2)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Max Temperature ({current_date})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, s=75, edgecolors="black", linewidths=2)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({current_date})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, s=75, edgecolors="black", linewidths=2)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({current_date})")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, s=75, edgecolors="black", linewidths=2)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s))")
plt.title(f"City Latitude vs. Wind Speed ({current_date})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots

def compute_and_plot_regression(x_values, y_values, x_label, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # if the slope is negative, add the annotation in the bottom left corner
    # otherwise put it in the bottom right corner
    if (slope < 0):
        line_x = x_values.min()
        line_y = y_values.min()
    else:
        line_x = (x_values.min() + x_values.max()) / 2
        line_y = y_values.min()
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.annotate(line_eq,(line_x, line_y), fontsize=15, color="red")
    print(f'The r-value is {rvalue**2}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
compute_and_plot_regression(x_values, y_values, "Latitude", "Temperature (C)")
# Out:
# The r-value is 0.7161472181434125

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
compute_and_plot_regression(x_values, y_values, "Latitude", "Temperature (C)")
# Out:
# The r-value is 0.4121057168607252

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
compute_and_plot_regression(x_values, y_values, "Latitude", "Humidity (%)")
# Out:
# The r-value is 0.05689741545789608

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
compute_and_plot_regression(x_values, y_values, "Latitude", "Humidity (%)")
# Out:
# The r-value is 0.0002808747046324618

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
compute_and_plot_regression(x_values, y_values, "Latitude", "Cloudiness (%)")
# Out:
# The r-value is 0.024026517125811043

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
compute_and_plot_regression(x_values, y_values, "Latitude", "Cloudiness (%)")
# Out:
# The r-value is 0.020567354299943663

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
compute_and_plot_regression(x_values, y_values, "Latitude", "Wind Speed (m/s)")
# Out:
# The r-value is 0.030396762354449474

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
compute_and_plot_regression(x_values, y_values, "Latitude", "Wind Speed (m/s)")
# Out:
# The r-value is 0.06223904070051575
